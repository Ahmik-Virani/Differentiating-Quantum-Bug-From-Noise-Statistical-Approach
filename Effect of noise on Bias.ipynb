# %%
from qiskit.circuit.random import random_circuit
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_aer.noise import NoiseModel
from qiskit_aer import AerSimulator
from qiskit import transpile
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

from math import log2
import numpy as np

# %%
def calculate_bias(output_map, unwanted_states):
    total_count = sum(output_map.values())

    bias = 0
    for key, val in output_map.items():
        if key in unwanted_states:
            bias += val / total_count
            
    return bias

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel="ibm_quantum", token='ce548974fc87b6f856990d2c1ca021d4c94fe6698b8b96ddb9c68bbea2880675d25b019a86b0eb832eaca814000f6fa01eb613d179fba9f9663bd41daba39689')
print(service.backends())
# Out:
# [<IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_kyiv')>, <IBMBackend('ibm_sherbrooke')>]

# %%
def generate_all_possible_outcomes(num_qubits):
    return {format(i, '0' + str(num_qubits) + 'b') for i in range(2**num_qubits)}

# %%
backends = ["ibm_brisbane", "ibm_kyiv", "ibm_sherbrooke"]
max_qubits = 12

# Define the desired mean and median of the lognormal distribution
desired_mean = 10
desired_median = 6.5
mu = np.log(desired_median)
sigma_squared = 2 * np.log(desired_mean / desired_median)
sigma = np.sqrt(sigma_squared)

counter = 0  # Counts circuits where (ideal bias < noisy bias)
failed_results = []  # Save circuits that did not satisfy this condition
for back in backends:
    # Initialize backend and noise model (requires service, see below)
    # Example with a QiskitRuntimeService instance:
    # backend = service.backend(back)
    # For this example we assume you have a valid backend object.
    backend = service.backend(back)
    noise_model = NoiseModel.from_backend(backend)
    
    # Run 1000 circuit experiments per backend
    for _ in range(1000):
        # Generate random qubit count from a lognormal distribution within [1, max_qubits]
        while True:
            q = np.random.lognormal(mean=mu, sigma=sigma)
            round_choice = np.random.choice([0, 1])  # 0 -> floor, 1 -> ceil
            q = np.floor(q) if round_choice == 0 else np.ceil(q)
            if q >= 1 and q <= max_qubits:
                break
        qubits = int(q)
        
        # Choose a random circuit depth (most experiments use shallow circuits)
        max_depth = 5
        depth = np.random.randint(1, max_depth + 1)
        
        # Generate a random circuit with measurements
        circ = random_circuit(qubits, depth, measure=True)
        
        # Create ideal and noisy simulators
        ideal_simulator = AerSimulator()
        noisy_simulator = AerSimulator(noise_model=noise_model)
        
        # Transpile for both simulators
        circ_ideal = transpile(circ, ideal_simulator)
        circ_noisy = transpile(circ, noisy_simulator)
        
        # Run simulations (using 100000 shots for statistics)
        ideal_result = ideal_simulator.run(circ_ideal, shots=100000).result()
        ideal_dist = ideal_result.get_counts()
        noisy_result = noisy_simulator.run(circ_noisy, shots=100000).result()
        noisy_dist = noisy_result.get_counts()
        
        # Define the target state and unwanted states.
        # Here the target state is the most likely outcome in the ideal simulation.
        all_possible = generate_all_possible_outcomes(qubits)
        unwanted_states = all_possible - set(ideal_dist.keys())
        
        # Calculate bias for both distributions
        bias_ideal = calculate_bias(ideal_dist, unwanted_states)
        bias_noisy = calculate_bias(noisy_dist, unwanted_states)
        
        # We expect that noise will generally increase the bias (i.e. probability in unwanted outcomes)
        if bias_ideal < bias_noisy:
            counter += 1
        else:
            failed_results.append(circ)

print("IBM backend experiment:")
print(f"Circuits with ideal bias < noisy bias: {counter}")
print(f"Circuits that did NOT satisfy the condition: {len(failed_results)}")

# %%
for circ in failed_results:
    num_qubits = circ.num_qubits
    circ_ideal = transpile(circ, ideal_simulator)
    circ_noisy = transpile(circ, noisy_simulator)
    ideal_result = ideal_simulator.run(circ_ideal, shots=100000).result()
    ideal_dist = ideal_result.get_counts()
    noisy_result = noisy_simulator.run(circ_noisy, shots=100000).result()
    noisy_dist = noisy_result.get_counts()
    target_state = max(ideal_dist, key=ideal_dist.get)
    unwanted_states = [s for s in ideal_dist if s != target_state]
    bias_ideal = calculate_bias(ideal_dist, unwanted_states)
    bias_noisy = calculate_bias(noisy_dist, unwanted_states)
    print(f"Num Qubits: {num_qubits}; Bias Ideal: {bias_ideal:.4f}; Bias Noisy: {bias_noisy:.4f}")
# Out:
# Num Qubits: 4; Bias Ideal: 0.6095; Bias Noisy: 0.5801
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.2477; Bias Noisy: 0.2666
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.4982; Bias Noisy: 0.0843
# Num Qubits: 4; Bias Ideal: 0.4972; Bias Noisy: 0.4280
# Num Qubits: 12; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.4998; Bias Noisy: 0.4753
# Num Qubits: 2; Bias Ideal: 0.4998; Bias Noisy: 0.4972
# Num Qubits: 8; Bias Ideal: 0.8785; Bias Noisy: 0.3652
# Num Qubits: 5; Bias Ideal: 0.6680; Bias Noisy: 0.6089
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.2789; Bias Noisy: 0.0965
# Num Qubits: 3; Bias Ideal: 0.5123; Bias Noisy: 0.5079
# Num Qubits: 2; Bias Ideal: 0.5000; Bias Noisy: 0.4781
# Num Qubits: 10; Bias Ideal: 0.4967; Bias Noisy: 0.0022
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.4983; Bias Noisy: 0.4448
# Num Qubits: 8; Bias Ideal: 0.7031; Bias Noisy: 0.5732
# Num Qubits: 3; Bias Ideal: 0.4941; Bias Noisy: 0.4607
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.3328; Bias Noisy: 0.0742
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.4275; Bias Noisy: 0.6430
# Num Qubits: 2; Bias Ideal: 0.4967; Bias Noisy: 0.4769
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.7835; Bias Noisy: 0.0167
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.7832; Bias Noisy: 0.8764
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.7755; Bias Noisy: 0.8463
# Num Qubits: 7; Bias Ideal: 0.3191; Bias Noisy: 0.0028
# Num Qubits: 8; Bias Ideal: 0.4995; Bias Noisy: 0.4376
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.7316; Bias Noisy: 0.7189
# Num Qubits: 6; Bias Ideal: 0.7117; Bias Noisy: 0.1424
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 9; Bias Ideal: 0.8493; Bias Noisy: 0.1938
# Num Qubits: 8; Bias Ideal: 0.1758; Bias Noisy: 0.1163
# Num Qubits: 7; Bias Ideal: 0.4981; Bias Noisy: 0.0713
# Num Qubits: 7; Bias Ideal: 0.5372; Bias Noisy: 0.3605
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.3100; Bias Noisy: 0.0209
# Num Qubits: 4; Bias Ideal: 0.2797; Bias Noisy: 0.2656
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.4598; Bias Noisy: 0.4279
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 12; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.8731; Bias Noisy: 0.4221
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.4000; Bias Noisy: 0.0406
# Num Qubits: 2; Bias Ideal: 0.4991; Bias Noisy: 0.4983
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.8044; Bias Noisy: 0.4208
# Num Qubits: 3; Bias Ideal: 0.4113; Bias Noisy: 0.4019
# Num Qubits: 6; Bias Ideal: 0.5000; Bias Noisy: 0.0307
# Num Qubits: 7; Bias Ideal: 0.8127; Bias Noisy: 0.4223
# Num Qubits: 7; Bias Ideal: 0.4985; Bias Noisy: 0.1451
# Num Qubits: 4; Bias Ideal: 0.3949; Bias Noisy: 0.4110
# Num Qubits: 8; Bias Ideal: 0.0748; Bias Noisy: 0.0017
# Num Qubits: 6; Bias Ideal: 0.8465; Bias Noisy: 0.3347
# Num Qubits: 10; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.7477; Bias Noisy: 0.7205
# Num Qubits: 5; Bias Ideal: 0.5765; Bias Noisy: 0.5253
# Num Qubits: 9; Bias Ideal: 0.5230; Bias Noisy: 0.0254
# Num Qubits: 6; Bias Ideal: 0.6119; Bias Noisy: 0.1612
# Num Qubits: 10; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 12; Bias Ideal: 0.6918; Bias Noisy: 0.0346
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 11; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 9; Bias Ideal: 0.5208; Bias Noisy: 0.0094
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 4; Bias Ideal: 0.7483; Bias Noisy: 0.6692
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.6573; Bias Noisy: 0.0082
# Num Qubits: 6; Bias Ideal: 0.4996; Bias Noisy: 0.2240
# Num Qubits: 4; Bias Ideal: 0.5550; Bias Noisy: 0.5212
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.3462; Bias Noisy: 0.3056
# Num Qubits: 8; Bias Ideal: 0.0557; Bias Noisy: 0.0433
# Num Qubits: 12; Bias Ideal: 0.9846; Bias Noisy: 0.7912
# Num Qubits: 7; Bias Ideal: 0.7474; Bias Noisy: 0.2137
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.2436; Bias Noisy: 0.0879
# Num Qubits: 12; Bias Ideal: 0.9680; Bias Noisy: 0.7827
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.5046; Bias Noisy: 0.0680
# Num Qubits: 4; Bias Ideal: 0.2489; Bias Noisy: 0.2245
# Num Qubits: 3; Bias Ideal: 0.5041; Bias Noisy: 0.5108
# Num Qubits: 9; Bias Ideal: 0.8840; Bias Noisy: 0.2314
# Num Qubits: 3; Bias Ideal: 0.4983; Bias Noisy: 0.4749
# Num Qubits: 7; Bias Ideal: 0.4981; Bias Noisy: 0.0514
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 11; Bias Ideal: 0.7334; Bias Noisy: 0.2701
# Num Qubits: 11; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.7753; Bias Noisy: 0.0516
# Num Qubits: 6; Bias Ideal: 0.8734; Bias Noisy: 0.6459
# Num Qubits: 9; Bias Ideal: 0.7530; Bias Noisy: 0.0070
# Num Qubits: 9; Bias Ideal: 0.4375; Bias Noisy: 0.0088
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.6710; Bias Noisy: 0.0746
# Num Qubits: 6; Bias Ideal: 0.6946; Bias Noisy: 0.3159
# Num Qubits: 5; Bias Ideal: 0.4992; Bias Noisy: 0.4206
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.6192; Bias Noisy: 0.6232
# Num Qubits: 4; Bias Ideal: 0.5237; Bias Noisy: 0.5265
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.1426; Bias Noisy: 0.1428
# Num Qubits: 7; Bias Ideal: 0.8838; Bias Noisy: 0.3888
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.5004; Bias Noisy: 0.4904
# Num Qubits: 6; Bias Ideal: 0.8636; Bias Noisy: 0.6408
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.8278; Bias Noisy: 0.1090
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.4973; Bias Noisy: 0.2089
# Num Qubits: 10; Bias Ideal: 0.1732; Bias Noisy: 0.0741
# Num Qubits: 7; Bias Ideal: 0.9423; Bias Noisy: 0.9340
# Num Qubits: 7; Bias Ideal: 0.5596; Bias Noisy: 0.1045
# Num Qubits: 5; Bias Ideal: 0.7884; Bias Noisy: 0.7680
# Num Qubits: 5; Bias Ideal: 0.4959; Bias Noisy: 0.4491
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.7769; Bias Noisy: 0.7921
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.8361; Bias Noisy: 0.0975
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.3751; Bias Noisy: 0.2720
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.3233; Bias Noisy: 0.2981
# Num Qubits: 8; Bias Ideal: 0.6057; Bias Noisy: 0.0875
# Num Qubits: 5; Bias Ideal: 0.4979; Bias Noisy: 0.4289
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 4; Bias Ideal: 0.4997; Bias Noisy: 0.4396
# Num Qubits: 8; Bias Ideal: 0.6422; Bias Noisy: 0.0476
# Num Qubits: 2; Bias Ideal: 0.4992; Bias Noisy: 0.4771
# Num Qubits: 9; Bias Ideal: 0.1875; Bias Noisy: 0.0085
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 11; Bias Ideal: 0.8788; Bias Noisy: 0.0519
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.4981; Bias Noisy: 0.2285
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.7464; Bias Noisy: 0.7149
# Num Qubits: 7; Bias Ideal: 0.7682; Bias Noisy: 0.2723
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.6248; Bias Noisy: 0.5857
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.4677; Bias Noisy: 0.4404
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.3626; Bias Noisy: 0.0803
# Num Qubits: 6; Bias Ideal: 0.0685; Bias Noisy: 0.0082
# Num Qubits: 4; Bias Ideal: 0.4995; Bias Noisy: 0.4666
# Num Qubits: 9; Bias Ideal: 0.7321; Bias Noisy: 0.0236
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.4977; Bias Noisy: 0.0150
# Num Qubits: 11; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 9; Bias Ideal: 0.4995; Bias Noisy: 0.0205
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 1; Bias Ideal: 0.4985; Bias Noisy: 0.4997
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.5258; Bias Noisy: 0.5176
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.4999; Bias Noisy: 0.4763
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.6189; Bias Noisy: 0.2822
# Num Qubits: 12; Bias Ideal: 0.7725; Bias Noisy: 0.1850
# Num Qubits: 5; Bias Ideal: 0.5014; Bias Noisy: 0.4582
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 12; Bias Ideal: 0.5026; Bias Noisy: 0.0717
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.2799; Bias Noisy: 0.0793
# Num Qubits: 9; Bias Ideal: 0.9521; Bias Noisy: 0.5201
# Num Qubits: 4; Bias Ideal: 0.7861; Bias Noisy: 0.7672
# Num Qubits: 11; Bias Ideal: 0.4964; Bias Noisy: 0.0160
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.7264; Bias Noisy: 0.7107
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.2446; Bias Noisy: 0.2443
# Num Qubits: 6; Bias Ideal: 0.7565; Bias Noisy: 0.3398
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.4970; Bias Noisy: 0.4473
# Num Qubits: 2; Bias Ideal: 0.4977; Bias Noisy: 0.4741
# Num Qubits: 3; Bias Ideal: 0.4969; Bias Noisy: 0.4573
# Num Qubits: 3; Bias Ideal: 0.3318; Bias Noisy: 0.3187
# Num Qubits: 5; Bias Ideal: 0.5254; Bias Noisy: 0.5175
# Num Qubits: 3; Bias Ideal: 0.5746; Bias Noisy: 0.5815
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.1112; Bias Noisy: 0.0562
# Num Qubits: 6; Bias Ideal: 0.7347; Bias Noisy: 0.4998
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.2042; Bias Noisy: 0.0326
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.8895; Bias Noisy: 0.5342
# Num Qubits: 4; Bias Ideal: 0.5587; Bias Noisy: 0.5822
# Num Qubits: 12; Bias Ideal: 0.6103; Bias Noisy: 0.0145
# Num Qubits: 8; Bias Ideal: 0.2989; Bias Noisy: 0.0969
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.6371; Bias Noisy: 0.2111
# Num Qubits: 12; Bias Ideal: 0.9433; Bias Noisy: 0.3841
# Num Qubits: 11; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.6822; Bias Noisy: 0.3249
# Num Qubits: 7; Bias Ideal: 0.7487; Bias Noisy: 0.0882
# Num Qubits: 9; Bias Ideal: 0.8808; Bias Noisy: 0.0239
# Num Qubits: 9; Bias Ideal: 0.7168; Bias Noisy: 0.0034
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.4989; Bias Noisy: 0.2084
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.1825; Bias Noisy: 0.0350
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.7122; Bias Noisy: 0.1170
# Num Qubits: 5; Bias Ideal: 0.1669; Bias Noisy: 0.1455
# Num Qubits: 6; Bias Ideal: 0.4981; Bias Noisy: 0.0281
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.8233; Bias Noisy: 0.2122
# Num Qubits: 8; Bias Ideal: 0.1859; Bias Noisy: 0.0060
# Num Qubits: 4; Bias Ideal: 0.5633; Bias Noisy: 0.5393
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.4937; Bias Noisy: 0.2783
# Num Qubits: 4; Bias Ideal: 0.1112; Bias Noisy: 0.1190
# Num Qubits: 5; Bias Ideal: 0.5676; Bias Noisy: 0.5496
# Num Qubits: 5; Bias Ideal: 0.3031; Bias Noisy: 0.2747
# Num Qubits: 8; Bias Ideal: 0.8733; Bias Noisy: 0.0686
# Num Qubits: 5; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.1122; Bias Noisy: 0.1057
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.6883; Bias Noisy: 0.1303
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 9; Bias Ideal: 0.5182; Bias Noisy: 0.1449
# Num Qubits: 5; Bias Ideal: 0.4786; Bias Noisy: 0.4506
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 6; Bias Ideal: 0.5077; Bias Noisy: 0.0855
# Num Qubits: 5; Bias Ideal: 0.5083; Bias Noisy: 0.4850
# Num Qubits: 5; Bias Ideal: 0.6262; Bias Noisy: 0.5551
# Num Qubits: 12; Bias Ideal: 0.7645; Bias Noisy: 0.0155
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.3975; Bias Noisy: 0.0193
# Num Qubits: 12; Bias Ideal: 0.1951; Bias Noisy: 0.0182
# Num Qubits: 8; Bias Ideal: 0.3731; Bias Noisy: 0.0557
# Num Qubits: 9; Bias Ideal: 0.7533; Bias Noisy: 0.0730
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.8710; Bias Noisy: 0.1299
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 4; Bias Ideal: 0.4977; Bias Noisy: 0.4639
# Num Qubits: 12; Bias Ideal: 0.9119; Bias Noisy: 0.4134
# Num Qubits: 11; Bias Ideal: 0.1554; Bias Noisy: 0.0320
# Num Qubits: 5; Bias Ideal: 0.6516; Bias Noisy: 0.6368
# Num Qubits: 3; Bias Ideal: 0.4995; Bias Noisy: 0.4731
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.4996; Bias Noisy: 0.0032
# Num Qubits: 4; Bias Ideal: 0.3618; Bias Noisy: 0.3297
# Num Qubits: 3; Bias Ideal: 0.4965; Bias Noisy: 0.4882
# Num Qubits: 6; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 5; Bias Ideal: 0.4998; Bias Noisy: 0.4656
# Num Qubits: 11; Bias Ideal: 0.5419; Bias Noisy: 0.1710
# Num Qubits: 8; Bias Ideal: 0.4980; Bias Noisy: 0.3928
# Num Qubits: 4; Bias Ideal: 0.7494; Bias Noisy: 0.7236
# Num Qubits: 6; Bias Ideal: 0.8280; Bias Noisy: 0.7387
# Num Qubits: 10; Bias Ideal: 0.8085; Bias Noisy: 0.3161
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.4991; Bias Noisy: 0.1376
# Num Qubits: 5; Bias Ideal: 0.7784; Bias Noisy: 0.7483
# Num Qubits: 7; Bias Ideal: 0.0121; Bias Noisy: 0.0105
# Num Qubits: 5; Bias Ideal: 0.5640; Bias Noisy: 0.5291
# Num Qubits: 6; Bias Ideal: 0.0882; Bias Noisy: 0.0185
# Num Qubits: 8; Bias Ideal: 0.6075; Bias Noisy: 0.0290
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.7153; Bias Noisy: 0.0122
# Num Qubits: 9; Bias Ideal: 0.8617; Bias Noisy: 0.2499
# Num Qubits: 10; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 11; Bias Ideal: 0.7591; Bias Noisy: 0.1338
# Num Qubits: 5; Bias Ideal: 0.3981; Bias Noisy: 0.4056
# Num Qubits: 6; Bias Ideal: 0.8091; Bias Noisy: 0.3017
# Num Qubits: 7; Bias Ideal: 0.4382; Bias Noisy: 0.1035
# Num Qubits: 8; Bias Ideal: 0.0527; Bias Noisy: 0.0205
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.7300; Bias Noisy: 0.0233
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.5985; Bias Noisy: 0.6009
# Num Qubits: 6; Bias Ideal: 0.7393; Bias Noisy: 0.6687
# Num Qubits: 9; Bias Ideal: 0.4549; Bias Noisy: 0.0116
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.4991; Bias Noisy: 0.0558
# Num Qubits: 3; Bias Ideal: 0.6802; Bias Noisy: 0.6659
# Num Qubits: 1; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.0718; Bias Noisy: 0.1839
# Num Qubits: 3; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.4996; Bias Noisy: 0.4747
# Num Qubits: 6; Bias Ideal: 0.4986; Bias Noisy: 0.4486
# Num Qubits: 9; Bias Ideal: 0.4990; Bias Noisy: 0.0168
# Num Qubits: 9; Bias Ideal: 0.5888; Bias Noisy: 0.0697
# Num Qubits: 10; Bias Ideal: 0.6766; Bias Noisy: 0.0309
# Num Qubits: 9; Bias Ideal: 0.7484; Bias Noisy: 0.0383
# Num Qubits: 8; Bias Ideal: 0.5478; Bias Noisy: 0.0598
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 10; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 4; Bias Ideal: 0.7507; Bias Noisy: 0.7209
# Num Qubits: 6; Bias Ideal: 0.2300; Bias Noisy: 0.2062
# Num Qubits: 9; Bias Ideal: 0.7648; Bias Noisy: 0.0234
# Num Qubits: 7; Bias Ideal: 0.5057; Bias Noisy: 0.5017
# Num Qubits: 4; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 2; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 8; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.7634; Bias Noisy: 0.0769
# Num Qubits: 8; Bias Ideal: 0.4998; Bias Noisy: 0.1125
# Num Qubits: 9; Bias Ideal: 0.0000; Bias Noisy: 0.0000
# Num Qubits: 7; Bias Ideal: 0.2047; Bias Noisy: 0.4102
# Num Qubits: 6; Bias Ideal: 0.6974; Bias Noisy: 0.3851
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       5 ideal_result = ideal_simulator.run(circ_ideal, shots=100000).result()
#       6 ideal_dist = ideal_result.get_counts()
# ----> 7 noisy_result = noisy_simulator.run(circ_noisy, shots=100000).result()
#       8 noisy_dist = noisy_result.get_counts()
#       9 target_state = max(ideal_dist, key=ideal_dist.get)
#
# File /opt/anaconda3/envs/qiskit_env/lib/python3.9/site-packages/qiskit_aer/jobs/utils.py:38, in requires_submit.<locals>._wrapper(self, *args, **kwargs)
#      36 if self._future is None:
#      37     raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 38 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit_env/lib/python3.9/site-packages/qiskit_aer/jobs/aerjob.py:96, in AerJob.result(self, timeout)
#      78 @requires_submit
#      79 def result(self, timeout=None):
#      80     # pylint: disable=arguments-differ
#      81     """Get job result. The behavior is the same as the underlying
#      82     concurrent Future objects,
#      83
#    (...)
#      94         concurrent.futures.CancelledError: if job cancelled before completed.
#      95     """
# ---> 96     return self._future.result(timeout=timeout)
#
# File /opt/anaconda3/envs/qiskit_env/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File /opt/anaconda3/envs/qiskit_env/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
